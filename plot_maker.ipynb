# %%
import matplotlib.pyplot as plt

# Data provided by the user
data = [[-0.8173152804374695, 0.07276596969781646], [-0.8493099808692932, 0.12167847474662798], [-0.8689957857131958, 0.14043140489196318], [-0.8738033175468445, 0.19648916019106316], [-0.8733474016189575, 0.17303388482867063], [-0.8718140125274658, 0.1521107772050852], [-0.8650586605072021, 0.1287324865160392], [-0.872725784778595, 0.16136721392819975], [-0.8661776185035706, 0.13622406195128134], [-0.870322048664093, 0.15021777277624374], [-0.8428861498832703, 0.10264893605911293], [-0.8655974268913269, 0.1306321944682243], [-0.8730158805847168, 0.17034598365808024]]

# Extracting the x and y values
x_values = [point[0] for point in data]
y_values = [point[1] for point in data]

# Plotting the data
plt.figure(figsize=(8, 6))
plt.scatter(x_values, y_values, color='blue')
plt.xlabel("Negative accuracy")
plt.ylabel("Disparate Impact difference regarding Sex")
plt.title("Pareto front with thresholds (0.001, 0.1)")
plt.grid(True)

# Display the plot
plt.show()

# %%
# Data provided by the user
data = [[-0.8491027355194092, 0.0803194793272752], [-0.8745078444480896, 0.13550687469893707], [-0.8647270798683167, 0.08964308680821793], [-0.8733474016189575, 0.12834289092262163], [-0.8694931268692017, 0.09526206833081391], [-0.8721041083335876, 0.10553701694736421], [-0.8721870183944702, 0.10847649401866269], [-0.8637324571609497, 0.08141825221910268], [-0.8703634738922119, 0.09745122998135047], [-0.8726014494895935, 0.11075988042678332], [-0.866509199142456, 0.09465176793312867], [-0.8730987310409546, 0.12282761467736662]]
# Extracting the x and y values
x_values = [point[0] for point in data]
y_values = [point[1] for point in data]

# Plotting the data
plt.figure(figsize=(8, 6))
plt.scatter(x_values, y_values, color='blue')
plt.xlabel("Negative accuracy")
plt.ylabel("Disparate Impact difference regarding Race")
plt.title("Pareto front with thresholds (0.001, 0.1)")
plt.grid(True)

# Display the plot
plt.show()

# %%
# Data provided by the user
data = [[-0.8735132217407227, 0.01620968150286095], [-0.8735546469688416, 0.02065927388728539], [-0.8723527789115906, 0.00232416831231963], [-0.8702805638313293, 0.00029621753000153017], [-0.8640225529670715, 0.00021140310901823778]]
# Extracting the x and y values
x_values = [point[0] for point in data]
y_values = [point[1] for point in data]

# Plotting the data
plt.figure(figsize=(8, 6))
plt.scatter(x_values, y_values, color='blue')
plt.xlabel("Negative accuracy")
plt.ylabel("Equal Opportunity difference regarding Race")
plt.title("Pareto front with thresholds (10, 0.1)")
plt.grid(True)

# Display the plot
plt.show()

# %%
# Data provided by the user
data = [[-0.7522483468055725, 0.0], [-0.8588005900382996, 0.00034979860080563974], [-0.8742591738700867, 0.0009336795986149005], [-0.8743835091590881, 0.05832803335453318], [-0.8706949949264526, 0.0008753798318140715], [-0.7522483468055725, 0.0], [-0.8683741688728333, 0.0005732810402091504]]

x_values = [point[0] for point in data]
y_values = [point[1] for point in data]

# Plotting the data
plt.figure(figsize=(8, 6))
plt.scatter(x_values, y_values, color='blue')
plt.xlabel("Negative accuracy")
plt.ylabel("Equal Opportunity difference regarding Sex")
plt.title("Pareto front with thresholds (10, 0.1)")
plt.grid(True)

# Display the plot
plt.show()
